# %% [markdown]
# # Stonks
#
# ### Dependencies and data

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Config
mpl.style.use('ggplot')
mpl.rcParams['figure.figsize'] = [16, 4]

# %%
# AAL data
aal_df = pd.read_csv('data/nasdaq/AAL.csv')
aal_df.head()
# Out:
#          Date        Low       Open   Volume       High      Close  \
# 0  27-09-2005  19.100000  21.049999   961200  21.400000  19.299999
# 1  28-09-2005  19.200001  19.299999  5747900  20.530001  20.500000
# 2  29-09-2005  20.100000  20.400000  1078200  20.580000  20.209999
# 3  30-09-2005  20.180000  20.260000  3123300  21.049999  21.010000
# 4  03-10-2005  20.900000  20.900000  1057900  21.750000  21.500000
#
#    Adjusted Close
# 0       18.194910
# 1       19.326199
# 2       19.052801
# 3       19.806999
# 4       20.268938

# %%
# Sort by date
aal_df['Date'] = pd.to_datetime(aal_df['Date']) # convert date to datetime
aal_df.sort_values('Date', inplace=True)
aal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3902 entries, 25 to 3890
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            3902 non-null   datetime64[ns]
#  1   Low             3902 non-null   float64
#  2   Open            3902 non-null   float64
#  3   Volume          3902 non-null   int64
#  4   High            3902 non-null   float64
#  5   Close           3902 non-null   float64
#  6   Adjusted Close  3902 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 243.9 KB

# %%
# Plot AAL
plt.plot(aal_df['Date'], aal_df['Close'])
plt.show()

# %%
# Filter for data after 2010
aal11_df = aal_df[aal_df['Date'].dt.year > 2010]
plt.plot(aal11_df['Date'], aal11_df['Close'])
plt.show()
