# %% [markdown]
# # Stonks
#
# ### Dependencies and data

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Config
mpl.style.use('ggplot')
mpl.rcParams['figure.figsize'] = [16, 4]

# %%
# Ticker A data
a_df = pd.read_csv('data/sp500/A.csv')
a_df.head()
# Out:
#          Date        Low       Open    Volume       High      Close  \
# 0  18-11-1999  28.612303  32.546494  62546380  35.765381  31.473534
# 1  19-11-1999  28.478184  30.713518  15234146  30.758226  28.880545
# 2  22-11-1999  28.657009  29.551144   6577870  31.473534  31.473534
# 3  23-11-1999  28.612303  30.400572   5975611  31.205294  28.612303
# 4  24-11-1999  28.612303  28.701717   4843231  29.998213  29.372318
#
#    Adjusted Close
# 0       27.212997
# 1       24.971014
# 2       27.212997
# 3       24.739080
# 4       25.396212

# %%
# Sort by date
a_df['Date'] = pd.to_datetime(a_df['Date']) # convert date to datetime
a_df.sort_values('Date', inplace=True)
a_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5373 entries, 8 to 5361
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            5373 non-null   datetime64[ns]
#  1   Low             5373 non-null   float64
#  2   Open            5373 non-null   float64
#  3   Volume          5373 non-null   int64
#  4   High            5373 non-null   float64
#  5   Close           5373 non-null   float64
#  6   Adjusted Close  5373 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 335.8 KB

# %%
# Plot A
plt.plot(a_df['Date'], a_df['Close'])
plt.show()

# %%
# Filter for data after 2010
a11_df = a_df[a_df['Date'].dt.year > 2010]
plt.plot(a11_df['Date'], a11_df['Close'])
plt.show()
